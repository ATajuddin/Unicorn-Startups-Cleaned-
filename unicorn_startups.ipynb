# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, date

# %%
df = pd.read_csv("Unicorn_Clean.csv")
df.drop("Unnamed: 0", axis = 1, inplace = True)
df
# Out:
#              Company  Valuation ($B) Date Joined        Country  \
# 0          Bytedance           140.0  2017-04-07          China
# 1             SpaceX           100.3  2012-12-01  United States
# 2             Stripe            95.0  2014-01-23  United States
# 3             Klarna            45.6  2011-12-12         Sweden
# 4              Canva            40.0  2018-01-08      Australia
# ..               ...             ...         ...            ...
# 931        YipitData             1.0  2021-12-06  United States
# 932         Anyscale             1.0  2021-12-07  United States
# 933  Iodine Software             1.0  2021-12-01  United States
# 934       ReliaQuest             1.0  2021-12-01  United States
# 935       Pet Circle             1.0  2021-12-07      Australia
#
#               City                         Industry  \
# 0          Beijing          Artificial intelligence
# 1        Hawthorne                            Other
# 2    San Francisco                          Fintech
# 3        Stockholm                          Fintech
# 4      Surry Hills     Internet software & services
# ..             ...                              ...
# 931       New York     Internet software & services
# 932       Berkeley          Artificial intelligence
# 933         Austin      Data management & analytics
# 934          Tampa                    Cybersecurity
# 935     Alexandria  E-commerce & direct-to-consumer
#
#                          Investor 1                 Investor 2  \
# 0             Sequoia Capital China       SIG Asia Investments
# 1                     Founders Fund    Draper Fisher Jurvetson
# 2                   Khosla Ventures           LowercaseCapital
# 3    Institutional Venture Partners            Sequoia Capital
# 4             Sequoia Capital China         Blackbird Ventures
# ..                              ...                        ...
# 931                   RRE Ventures+  Highland Capital Partners
# 932             Andreessen Horowitz              Intel Capital
# 933            Advent International      Bain Capital Ventures
# 934                             KKR                FTV Capital
# 935                   Prysm Capital      Baillie Gifford & Co.
#
#                        Investor 3      Investor 4
# 0                      Sina Weibo  Softbank Group
# 1             Rothenberg Ventures             NaN
# 2                        capitalG             NaN
# 3                General Atlantic             NaN
# 4                 Matrix Partners             NaN
# ..                            ...             ...
# 931             The Carlyle Group             NaN
# 932            Foundation Capital             NaN
# 933  Silversmith Capital Partners             NaN
# 934           Ten Eleven Ventures             NaN
# 935           TDM Growth Partners             NaN
#
# [936 rows x 10 columns]

# %%
df["City"].replace({"United States": "Santa Clara"}, inplace = True)
df["Country"].replace({"Hong Kong": "China", "Santa Clara": "United States"}, inplace=True)

# %% [markdown]
# ## *Number of unicorn startups per country*

# %%
plt.rcParams["figure.figsize"] = (15,10)

sns.set(style="white")

plot = sns.countplot(y = 'Country',
              data= df,
              order = df.value_counts('Country').iloc[:10].index,
              orient = 'h',
              color = 'grey')

sns.despine(bottom = False, left = True)

plt.xlabel("Count", size=15)
plt.ylabel("Country", size=15)


plot.set_title('Top 10 Countries With the Highest Number of Unicorn Startups\n', size = 20);
for p in plot.patches:
    width = p.get_width()
    plt.text(10+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ### *Which city has the most unicorn startups in the United States?*

# %%
plot = sns.countplot(y = df['City'].loc[df['Country'] == 'United States'],
              order = df.loc[df['Country'] == 'United States'].value_counts('City').iloc[:10].index,
              orient = 'h',
              color = 'grey')

sns.despine(bottom = False, left = True)

plt.xlabel("Count", size=15)
plt.ylabel("City", size=15)
plot.set_title('Top 10 Cities With the Highest Number of Unicorn Startups in USA\n', size = 20);
for p in plot.patches:
    width = p.get_width()
    plt.text(3+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center')

plt.show()

# %% [markdown]
# ## *Unicorn startups valuation for each country*

# %%
plt.figure(figsize=(15,10))
plot = sns.stripplot(y = 'Country',
                   x = 'Valuation ($B)',
                   data = df,
                   orient = 'h',
                   color = 'grey')

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Unicorns Valuations in Each Country ($B)\n', size = 20);
plt.xlabel("Valuation ($B)\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Country", size=15)

plt.show()

# %% [markdown]
# ## *Most valued companies*

# %%
plot = sns.barplot(y = 'Company',
                   x = 'Valuation ($B)',
                   data = df,
                   orient = 'h',
                   color = 'grey',
                   order = df.loc[df['Valuation ($B)'] > 20].value_counts('Company').iloc[:].index)

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Most Valued Companies ($B)\n', size = 20);
plt.xlabel("Valuation ($B)\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Country", size=15)

for bar in plot.patches:
    if bar.get_width() == 140:
        bar.set_color('blue')    
    else:
        bar.set_color('grey')

plt.show()

# %% [markdown]
# ## *The valuation for each industry*

# %%
df_new = df.copy()
# Sum the valuation for each industry
df_new['industry_val'] = df_new.groupby('Industry')['Valuation ($B)'].transform('sum')

# %%
plot = sns.barplot(y = 'Industry',
                   x = 'industry_val',
                   data = df_new,
                   orient = 'h',
                   color = 'grey', 
                   order = df_new.value_counts('Industry').iloc[:].index)

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Top 3 Industries Valuation ($B)\n', size = 20);
plt.xlabel("Valuation ($B)\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Industry", size=15)

lst = np.sort(list(df_new['industry_val'].value_counts().index))
lst = list(lst[-3:])

for bar in plot.patches:
    if round(bar.get_width(), 2) in lst:
        bar.set_color('blue')    
    else:
        bar.set_color('grey')

plt.show()

# %% [markdown]
# ## *Age of the company and its valuation*

# %%
def age(born):
    born = datetime.strptime(born, "%Y-%m-%d").date()
    today = date.today()
    return today.year - born.year - ((today.month, 
                                      today.day) < (born.month, 
                                                    born.day))
  
df_new['Age'] = df_new['Date Joined'].apply(age)

# %%
plot = sns.countplot(y = 'Age',
                   data = df_new,
                   orient = 'h',
                   color = 'grey')

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Ages of Unicorn Startups\n', size = 20);
plt.xlabel("Count\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Age (Years)", size=15)

plt.show()

# %%
plot = sns.boxplot(x = 'Valuation ($B)',
                   y = 'Age',
                   data = df_new,
                   orient = 'h',
                   color = 'grey')

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Ages of Companies Compared to their Valuations ($B)\n', size = 20);
plt.xlabel("Valuation ($B)\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Age (years)", size=15)

plt.show()

# %% [markdown]
# ## *Ages of Unicorn Startups within Each Industry*

# %%
plot = sns.boxplot(y = 'Industry',
                   x = 'Age',
                   data = df_new,
                   orient = 'h',
                   color = 'grey', 
                   order = df_new.value_counts('Industry').iloc[:].index)

sns.despine(bottom = True, left = True, top = False)

plot.set_title('Ages of Unicorn Startups within Each Industry\n', size = 20);
plt.xlabel("Age (Years)\n", size=15)
plot.xaxis.set_ticks_position("top")
plot.xaxis.set_label_position('top')
plt.ylabel("Industry", size=15);

# %%
#visualization for seeing the correlation
df1 = pd.read_csv("Unicorn_Clean.csv")
sns.pairplot(df1)

# %%
plt.figure(figsize=(6,6))
sns.heatmap(np.abs(df1.corr()), annot = True, cmap = "viridis", fmt = "0.2f")

# %%
#relationship analysis
#correlation analysis
cor = df1.corr()
cor
# Out:
#                 Unnamed: 0  Valuation ($B)
# Unnamed: 0        1.000000       -0.403606
# Valuation ($B)   -0.403606        1.000000

# %%
df1.value_counts()
# Out:
# Unnamed: 0  Company     Valuation ($B)  Date Joined  Country        City           Industry                           Investor 1             Investor 2            Investor 3                        Investor 4
# 0           Bytedance   140.00          2017-04-07   China          Beijing        Artificial intelligence            Sequoia Capital China  SIG Asia Investments  Sina Weibo                        Softbank Group         1
# 26          SenseTime   12.00           2017-07-11   China          Shanghai       Artificial intelligence            Star VC                IDG Capital           Infore Capital                    Alibaba Group          1
# 52          Niantic     9.00            2017-11-24   United States  San Francisco  Mobile & telecommunications        Nintendo               Google                Pokemon Company International     Spark Capital          1
# 106         Rappi       5.25            2018-08-31   Colombia       Bogota         Supply chain logistics & delivery  DST Global             Andreessen Horowitz   Sequoia Capital                   Redpoint e.ventures    1
# 225         Yixia       3.00            2015-11-24   China          Beijing        Mobile & telecommunications        Sequoia Capital China  Sina Weibo            Kleiner Perkins Caufield & Byers  Redpoint Ventures      1
# 427         Lightricks  1.80            2019-07-31   Israel         Jerusalem      Artificial intelligence            Viola Ventures         Insight Partners      ClalTech                          Goldman Sachs          1
# 808         Skydio      1.00            2021-02-25   United States  Redwood City   Supply chain logistics & delivery  Andreessen Horowitz    Andreessen Horowitz   Institutional Venture Partners    Accel                  1
# dtype: int64
